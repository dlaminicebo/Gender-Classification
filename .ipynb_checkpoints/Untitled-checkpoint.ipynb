# %%
#217460972 C Dlamini

# %%
# %tensorflow_version 2.x
# Out:
# UsageError: Line magic function `%tensorflow_version` not found.

# %%
import numpy as np
import pandas as pd
from glob import glob
import matplotlib.pyplot as plt
# %matplotlib inline

from keras.layers import Dense, InputLayer
from keras.models import Sequential

from sklearn.model_selection import train_test_split

# %%
data_1 = pd.read_csv('train.csv')

# %%
data_1.head()
# Out:
#   image_names  class
# 0   11413.jpg      1
# 1    9863.jpg      1
# 2     997.jpg      0
# 3    5950.jpg      0
# 4   10454.jpg      1

# %%
data_2 = pd.read_csv('test_fkwGUNG.csv')

# %%
data_2.head()
# Out:
#   image_names
# 0    5603.jpg
# 1    1286.jpg
# 2    9815.jpg
# 3    8865.jpg
# 4    9306.jpg

# %%
# create random number generator
seed = 42
rng = np.random.RandomState(seed)

# %%
# distribution of classes in the dataset
data_1['class'].value_counts()
# Out:
# class
# 1    6174
# 0    6022
# Name: count, dtype: int64

# %%
# load images and store it in numpy array

# empty list to store the images
X = []
# iterating over each image
for img_name in data_1.image_names:
    # loading the image using its name
    img = plt.imread('images/' + img_name)
    # saving each image in the list
    X.append(img)
    
# converting the list of images into array
X=np.array(X)

# storing the target variable in separate variable
y = data_1['class'].values
#y = data_1.class.values
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[13], line 8
#       5 # iterating over each image
#       6 for img_name in data_1.image_names:
#       7     # loading the image using its name
# ----> 8     img = plt.imread('images/' + img_name)
#       9     # saving each image in the list
#      10     X.append(img)
#
# File ~\anaconda3\Lib\site-packages\matplotlib\pyplot.py:2389, in imread(fname, format)
#    2385 @_copy_docstring_and_deprecators(matplotlib.image.imread)
#    2386 def imread(
#    2387         fname: str | pathlib.Path | BinaryIO, format: str | None = None
#    2388 ) -> np.ndarray:
# -> 2389     return matplotlib.image.imread(fname, format)
#
# File ~\anaconda3\Lib\site-packages\matplotlib\image.py:1525, in imread(fname, format)
#    1518 if isinstance(fname, str) and len(parse.urlparse(fname).scheme) > 1:
#    1519     # Pillow doesn't handle URLs directly.
#    1520     raise ValueError(
#    1521         "Please open the URL for reading and pass the "
#    1522         "result to Pillow, e.g. with "
#    1523         "``np.array(PIL.Image.open(urllib.request.urlopen(url)))``."
#    1524         )
# -> 1525 with img_open(fname) as image:
#    1526     return (_pil_png_to_float_array(image)
#    1527             if isinstance(image, PIL.PngImagePlugin.PngImageFile) else
#    1528             pil_to_array(image))
#
# File ~\anaconda3\Lib\site-packages\PIL\Image.py:3247, in open(fp, mode, formats)
#    3244     filename = fp
#    3246 if filename:
# -> 3247     fp = builtins.open(filename, "rb")
#    3248     exclusive_fp = True
#    3250 try:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'images/11413.jpg'

# %%
X.shape
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 X.shape
#
# AttributeError: 'list' object has no attribute 'shape'

# %%
# visualizing images
fig,ax = plt.subplots(nrows=1,ncols=5,figsize=(20,20))
for i in range(5):
    ax[i].imshow(X[i*400])
    ax[i].axis('off')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[15], line 4
#       2 fig,ax = plt.subplots(nrows=1,ncols=5,figsize=(20,20))
#       3 for i in range(5):
# ----> 4     ax[i].imshow(X[i*400])
#       5     ax[i].axis('off')
#
# IndexError: list index out of range

# %%
# converting 3 dimensional image to 1 dimensional image
X = X.reshape(X.shape[0], 224*224*3)
X.shape
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[16], line 2
#       1 # converting 3 dimensional image to 1 dimensional image
# ----> 2 X = X.reshape(X.shape[0], 224*224*3)
#       3 X.shape
#
# AttributeError: 'list' object has no attribute 'reshape'

# %%
X.min(), X.max()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 X.min(), X.max()
#
# AttributeError: 'list' object has no attribute 'min'

# %%
#NORMALIZED
# minimum and maximum pixel values of images after normalizing
X.min(), X.max()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[19], line 2
#       1 # minimum and maximum pixel values of images after normalizing
# ----> 2 X.min(), X.max()
#
# AttributeError: 'list' object has no attribute 'min'

# %%
#CREATING TRAINING AND TESTING MODEL

# %%
# creating a training and validation set
X_train, X_valid, y_train, y_valid=train_test_split(X,y,test_size=0.3, random_state=seed)
# shape of training and validation set
(X_train.shape, y_train.shape), (X_valid.shape, y_valid.shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 2
#       1 # creating a training and validation set
# ----> 2 X_train, X_valid, y_train, y_valid=train_test_split(X,y,test_size=0.3, random_state=seed)
#       3 # shape of training and validation set
#       4 (X_train.shape, y_train.shape), (X_valid.shape, y_valid.shape)
#
# NameError: name 'y' is not defined

# %%
#Defining the mode;l architecture

# %%
model=Sequential()
model.add(InputLayer(input_shape=(X_train.shape[1],)))
model.add(Dense(100, activation='sigmoid'))
model.add(Dense(units=1, activation='sigmoid'))
model.summary()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 2
#       1 model=Sequential()
# ----> 2 model.add(InputLayer(input_shape=(X_train.shape[1],)))
#       3 model.add(Dense(100, activation='sigmoid'))
#       4 model.add(Dense(units=1, activation='sigmoid'))
#
# NameError: name 'X_train' is not defined

# %%
Model: "sequential_5"

# %%
#COMPI

# %%
#COMPLING THE MODEL NGAPDEZULU IS NOT MAKE SURE

# %%
# compiling the model
model.compile(loss='binary_crossentropy', optimizer="sgd", metrics=['accuracy'])

# %%
# training the model
model_history = model.fit(X_train, y_train, epochs=50, batch_size=128,validation_data=(X_valid,y_valid))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[28], line 2
#       1 # training the model
# ----> 2 model_history = model.fit(X_train, y_train, epochs=50, batch_size=128,validation_data=(X_valid,y_valid))
#
# NameError: name 'X_train' is not defined

# %%
# Assuming model is your trained Keras Sequential model
# Assuming X_valid is your validation data

# Get the probabilities for each class
prediction_probabilities = model.predict(X_valid)

# Extract the class with the highest probability for each prediction
predictions = prediction_probabilities.argmax(axis=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[29], line 5
#       1 # Assuming model is your trained Keras Sequential model
#       2 # Assuming X_valid is your validation data
#       3
#       4 # Get the probabilities for each class
# ----> 5 prediction_probabilities = model.predict(X_valid)
#       7 # Extract the class with the highest probability for each prediction
#       8 predictions = prediction_probabilities.argmax(axis=1)
#
# NameError: name 'X_valid' is not defined

# %%
from sklearn.metrics import accuracy_score
print('Accuracy on validation set:', accuracy_score(y_valid, predictions), '%')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[30], line 2
#       1 from sklearn.metrics import accuracy_score
# ----> 2 print('Accuracy on validation set:', accuracy_score(y_valid, predictions), '%')
#
# NameError: name 'y_valid' is not defined

# %%
# summarize history for loss
plt.plot(model_history.history['loss'])
plt.plot(model_history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[31], line 2
#       1 # summarize history for loss
# ----> 2 plt.plot(model_history.history['loss'])
#       3 plt.plot(model_history.history['val_loss'])
#       4 plt.title('model loss')
#
# NameError: name 'model_history' is not defined

# %%
# summarize history for accuracy
plt.plot(model_history.history['accuracy'])
plt.plot(model_history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[32], line 2
#       1 # summarize history for accuracy
# ----> 2 plt.plot(model_history.history['accuracy'])
#       3 plt.plot(model_history.history['val_accuracy'])
#       4 plt.title('model accuracy')
#
# NameError: name 'model_history' is not defined

# %%
# pull out the original images from the data which correspond to the validation data
_, valid_Gender, _, valid_y = train_test_split(data_1.image_names.values, y, test_size=0.3, random_state=seed)

# get a random index to plot image randomly
index = rng.choice(range(len(valid_Gender)))

# get the corresponding image name and probability
img_name = valid_Gender[index]
prob = (prediction_probabilities * 100).astype(int)[index]

# read the image
img = plt.imread('images/' + img_name)

# print probability and actual class
print('Model is', prob , '% sure that it is female')
print('And actual class is ', valid_y[index])

# plot image
plt.imshow(img)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[33], line 2
#       1 # pull out the original images from the data which correspond to the validation data
# ----> 2 _, valid_Gender, _, valid_y = train_test_split(data_1.image_names.values, y, test_size=0.3, random_state=seed)
#       4 # get a random index to plot image randomly
#       5 index = rng.choice(range(len(valid_Gender)))
#
# NameError: name 'y' is not defined

# %%
# using relu as activation function in hidden layer
model=Sequential()
model.add(InputLayer(input_shape=(X_train.shape[1],)))
model.add(Dense(100, activation='relu'))
model.add(Dense(units=1, activation='sigmoid'))

# compiling the model
model.compile(loss='binary_crossentropy', optimizer="sgd", metrics=['accuracy'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[34], line 3
#       1 # using relu as activation function in hidden layer
#       2 model=Sequential()
# ----> 3 model.add(InputLayer(input_shape=(X_train.shape[1],)))
#       4 model.add(Dense(100, activation='relu'))
#       5 model.add(Dense(units=1, activation='sigmoid'))
#
# NameError: name 'X_train' is not defined

# %%
# summary of the model
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
# training the model for 50 epochs
model_history = model.fit(X_train, y_train, epochs=50, batch_size=128,validation_data=(X_valid,y_valid))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[36], line 2
#       1 # training the model for 50 epochs
# ----> 2 model_history = model.fit(X_train, y_train, epochs=50, batch_size=128,validation_data=(X_valid,y_valid))
#
# NameError: name 'X_train' is not defined

# %%
import numpy as np

# Assuming `model` is your Sequential model
raw_predictions = model.predict(X_valid)
predicted_classes = np.argmax(raw_predictions, axis=1)

# Now you can calculate accuracy using predicted_classes
accuracy = np.mean(predicted_classes == y_valid)
print('Accuracy on validation set:', accuracy, '%')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[37], line 4
#       1 import numpy as np
#       3 # Assuming `model` is your Sequential model
# ----> 4 raw_predictions = model.predict(X_valid)
#       5 predicted_classes = np.argmax(raw_predictions, axis=1)
#       7 # Now you can calculate accuracy using predicted_classes
#
# NameError: name 'X_valid' is not defined

# %%
# summarize history for loss
plt.plot(model_history.history['loss'])
plt.plot(model_history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[38], line 2
#       1 # summarize history for loss
# ----> 2 plt.plot(model_history.history['loss'])
#       3 plt.plot(model_history.history['val_loss'])
#       4 plt.title('model loss')
#
# NameError: name 'model_history' is not defined

# %%
# increase hidden neurons
model=Sequential()
model.add(InputLayer(input_shape=(X_train.shape[1],)))
model.add(Dense(1024, activation='sigmoid'))
model.add(Dense(units=1, activation='sigmoid'))

# compiling the model
model.compile(loss='binary_crossentropy', optimizer="sgd", metrics=['accuracy'])
# model summary
model.summary()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[39], line 3
#       1 # increase hidden neurons
#       2 model=Sequential()
# ----> 3 model.add(InputLayer(input_shape=(X_train.shape[1],)))
#       4 model.add(Dense(1024, activation='sigmoid'))
#       5 model.add(Dense(units=1, activation='sigmoid'))
#
# NameError: name 'X_train' is not defined

# %%
model_history = model.fit(X_train, y_train, epochs=50, batch_size=128,validation_data=(X_valid,y_valid))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 model_history = model.fit(X_train, y_train, epochs=50, batch_size=128,validation_data=(X_valid,y_valid))
#
# NameError: name 'X_train' is not defined

# %%
import numpy as np
from sklearn.metrics import accuracy_score

# Assuming model is your Sequential model
y_pred_probabilities = model.predict(X_valid)
y_pred_classes = np.argmax(y_pred_probabilities, axis=1)
accuracy = accuracy_score(y_valid, y_pred_classes)
print('Accuracy on validation set:', accuracy , '%')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[41], line 5
#       2 from sklearn.metrics import accuracy_score
#       4 # Assuming model is your Sequential model
# ----> 5 y_pred_probabilities = model.predict(X_valid)
#       6 y_pred_classes = np.argmax(y_pred_probabilities, axis=1)
#       7 accuracy = accuracy_score(y_valid, y_pred_classes)
#
# NameError: name 'X_valid' is not defined

# %%
# summarize history for loss
plt.plot(model_history.history['loss'])
plt.plot(model_history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[42], line 2
#       1 # summarize history for loss
# ----> 2 plt.plot(model_history.history['loss'])
#       3 plt.plot(model_history.history['val_loss'])
#       4 plt.title('model loss')
#
# NameError: name 'model_history' is not defined

# %%
# increase hidden layers
model=Sequential()
model.add(InputLayer(input_shape=(X_train.shape[1],)))
model.add(Dense(100, activation='sigmoid'))
model.add(Dense(100, activation='sigmoid'))
model.add(Dense(units=1, activation='sigmoid'))

# compiling the model
model.compile(loss='binary_crossentropy', optimizer="sgd", metrics=['accuracy'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[43], line 3
#       1 # increase hidden layers
#       2 model=Sequential()
# ----> 3 model.add(InputLayer(input_shape=(X_train.shape[1],)))
#       4 model.add(Dense(100, activation='sigmoid'))
#       5 model.add(Dense(100, activation='sigmoid'))
#
# NameError: name 'X_train' is not defined

# %%
# model summary
model.summary()
# Out:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
model_history = model.fit(X_train, y_train, epochs=50, batch_size=128,validation_data=(X_valid,y_valid))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 model_history = model.fit(X_train, y_train, epochs=50, batch_size=128,validation_data=(X_valid,y_valid))
#
# NameError: name 'X_train' is not defined
